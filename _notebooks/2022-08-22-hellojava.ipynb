// %% [markdown]
// # Java Notebook
// > Code for Java
//
// - toc: true
// - badges: true
// - comments: true
// - categories: [jupyter]
// - image: images/chart-preview.png
// - title: Java Notebook

// %%
System.out.println("Hello World");
// Out:
// Hello World
